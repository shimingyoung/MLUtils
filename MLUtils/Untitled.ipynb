# %%
import performance as perf

# %%
import mlutils

# %%
from mlutils import performance as perf

# %%
import pandas as pd

# %%
file = 'C:/projects/NW/RAPIDTBI_MasterFile_n905_03MAR2021.xlsx'

# %%
data = pd.read_excel(file)

# %%
data.describe()
# Out:
#           ACCOUNTNO       TRAUMANO      MEDRECNO   TMPMEDRECNO  sex_binary  \
# count  9.050000e+02     905.000000  9.050000e+02  9.050000e+02  905.000000
# mean   1.806532e+08  310489.149171  2.108872e+09  2.927361e+09    0.664088
# std    3.076450e+05    5445.202748  1.371352e+09  4.620205e+08    0.472569
# min    1.801061e+08  300597.000000  3.365000e+04  3.477280e+05    0.000000
# 25%    1.804014e+08  305966.000000  2.079216e+06  3.000142e+09    0.000000
# 50%    1.806209e+08  310304.000000  3.000155e+09  3.000254e+09    1.000000
# 75%    1.809142e+08  315163.000000  3.000313e+09  3.000355e+09    1.000000
# max    1.811874e+08  319883.000000  3.000428e+09  3.000429e+09    1.000000
#
#               AGE     ADMTIME      DCTIME     INJTIME         LOS  ...  \
# count  905.000000  905.000000  905.000000  905.000000  905.000000  ...
# mean    54.142541    0.576848    0.676993    0.568191    8.686535  ...
# std     21.891188    0.275944    0.149019    0.268447    8.546815  ...
# ...

# %%
data.groupby(by=['sex_binary']).count()
# Out:
#             STUDYID  ACCOUNTNO  TRAUMANO  MEDRECNO  TMPMEDRECNO  \
# sex_binary
# 0               304        304       304       304          304
# 1               601        601       601       601          601
#
#             HOSPITALARRIVALTIME  SEXID  RACEID  race_descrip  AGE  ...  \
# sex_binary                                                         ...
# 0                           304    304     304           304  304  ...
# 1                           601    601     601           601  601  ...
#
#             S1S2ratio_3rdquatile  S1S2ratio_max  S1S2ratio_mode  \
# sex_binary
# 0                            293            293             293
# 1                            584            584             584
#
#             dnotch_pos_speed_dur_min  dnotch_pos_speed_dur_1stquatile  \
# sex_binary
# 0                                293                              293
# 1                                584                              584
#
# ...
